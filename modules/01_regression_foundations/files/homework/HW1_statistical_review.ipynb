# %% [markdown]
# # Homework 1: Statistical Review
#
# This notebook is an editable homework template for the statistical review material used before simple linear regression.
#
# You may complete this assignment in JupyterLite and export a PDF report, or you may complete it in another environment, in your own local Python/Jupyter environment or other approved tools, or by handwriting the written parts. The goal is to solve the problems clearly and submit work according to the course instructions.
#
# If you use this notebook, write explanations in Markdown cells using LaTeX where helpful, run the code cells you use, then submit both the completed `.ipynb` and a PDF report.
#
# ---
#
# ## Student Information
#
# Complete this section before submitting.
#
# | Field | Response |
# |---|---|
# | Name | **ANSWER:** |
# | Georgia Tech email | **ANSWER:** |
# | GTID | **ANSWER:** |

# %%
import sys
from pathlib import Path

# Homework notebooks may be opened from the module root or from the homework/ folder.
if not Path("lite_setup.py").exists() and Path("../lite_setup.py").exists():
    sys.path.append("..")

from lite_setup import ensure_packages
await ensure_packages()
import numpy as np
import pandas as pd
from scipy import stats

# %% [markdown]
# <hr>
#
# ## Working Style
#
# For written cells, replace the prompt text with your answer. Use LaTeX notation such as `$H_0: \mu = 155$`, `$z = \frac{\bar{x}-\mu_0}{\sigma/\sqrt{n}}$`, and display equations when useful.
#
# For code cells, the required packages are already loaded above. Fill in the TODO sections, run the cells, and use the numerical output to support your written conclusion.
#
# For PDF reports, the horizontal lines mark major sections. If you include screenshots or other images, Markdown image links are useful for previewing them in the notebook, but the PDF exporter is more reliable when the image is also displayed from a code cell as notebook output. Use the example in the AI Usage Report section.

# %% [markdown]
# <hr>
#
# ## Problem 1
#
# A melting point test of `n = 10` samples of a binder used in manufacturing a rocket propellant resulted in $\bar{x} = 154.2^\circ F$. Assume that the melting point is normally distributed with $\sigma = 1.5^\circ F$.
#
# 1. Test $H_0: \mu = 155$ versus $H_1: \mu \ne 155$ using $\alpha = 0.01$.
# 2. What is the p-value for this test?
# 3. What is the probability of committing a Type II error, $\beta$, if the true mean is $\mu = 150$?

# %% [markdown]
# ### Problem 1 Written Answer
#
# Write your hypotheses, test statistic, rejection rule or p-value decision, and conclusion here. For the Type II error part, explain the acceptance region under $H_0$ and evaluate its probability under $\mu = 150$.
#
# **ANSWER:**
#
# Write your answer here.

# %%
# Problem 1 computation
n = 10
xbar = 154.2
mu0 = 155
sigma = 1.5
alpha = 0.01
mu_true = 150

# TODO: compute the z statistic and two-sided p-value.
# z_stat = ...
# p_value = ...

# TODO: compute the two-sided acceptance region for xbar under H0.
# z_crit = ...
# lower_accept = ...
# upper_accept = ...

# TODO: compute beta when the true mean is mu_true.
# beta = ...

# Print your results clearly.

# %% [markdown]
# <hr>
#
# ## Problem 2
#
# The brightness of a television picture tube can be evaluated by measuring the amount of current required to achieve a particular brightness level. A sample of 10 tubes results in $\bar{x} = 317.2$ and $s = 15.7$.
#
# Find a 99% confidence interval, in microamps, for the mean current required. State any necessary assumptions about the underlying distribution of the data.

# %% [markdown]
# ### Problem 2 Written Answer
#
# Write the confidence interval formula, identify the critical value you need, state the interval, and interpret it in context. Also state the distributional assumption needed for this small-sample interval.
#
# **ANSWER:**
#
# Write your answer here.

# %%
# Problem 2 computation
n = 10
xbar = 317.2
s = 15.7
confidence = 0.99
alpha = 1 - confidence

# TODO: compute the t critical value, margin of error, and confidence interval.
# t_crit = ...
# margin = ...
# ci = (..., ...)

# Print your interval clearly.

# %% [markdown]
# <hr>
#
# ## Problem 3
#
# Consider the hypothesis test $H_0: \mu_1 = \mu_2$ against $H_1: \mu_1 \ne \mu_2$.
#
# Suppose that $n_1 = 15$, $n_2 = 15$, $\bar{x}_1 = 4.7$, $\bar{x}_2 = 7.8$, $s_1^2 = 4$, and $s_2^2 = 6.25$. Assume that $\sigma_1^2 = \sigma_2^2$ and that the data are drawn from normal distributions. Use $\alpha = 0.05$.
#
# 1. Test the hypothesis.
# 2. Find the p-value.

# %% [markdown]
# ### Problem 3 Written Answer
#
# Write the pooled-variance two-sample t-test setup. Include the pooled variance, degrees of freedom, test statistic, p-value, and conclusion in context.
#
# **ANSWER:**
#
# Write your answer here.

# %%
# Problem 3 computation
n1, n2 = 15, 15
xbar1, xbar2 = 4.7, 7.8
s1_sq, s2_sq = 4.0, 6.25
alpha = 0.05

# TODO: compute pooled variance, standard error, t statistic, degrees of freedom, and p-value.
# sp_sq = ...
# se = ...
# t_stat = ...
# df = ...
# p_value = ...

# Print your results clearly.

# %% [markdown]
# <hr>
#
# ## Problem 4
#
# Two chemical companies can supply a raw material. The concentration of a particular element in this material is important. The mean concentration for both suppliers is the same, but you suspect that the variability in concentration may differ for the two companies.
#
# The standard deviation of concentration in a random sample of $n_1 = 10$ batches produced by company 1 is $s_1 = 4.7$ grams per liter. For company 2, a random sample of $n_2 = 16$ batches yields $s_2 = 5.8$ grams per liter.
#
# Is there sufficient evidence to conclude that the two population variances differ? Use $\alpha = 0.05$.

# %% [markdown]
# ### Problem 4 Written Answer
#
# Write the hypotheses for a two-sided variance comparison, define your F statistic, give the p-value or critical-value decision, and state the conclusion in context.
#
# **ANSWER:**
#
# Write your answer here.

# %%
# Problem 4 computation
n1, n2 = 10, 16
s1, s2 = 4.7, 5.8
alpha = 0.05

# TODO: compute an F statistic for the variance ratio and the two-sided p-value.
# Put the larger sample variance in the numerator if you use the doubled upper-tail method.
# f_stat = ...
# df_num = ...
# df_den = ...
# p_value = ...

# Print your results clearly.

# %% [markdown]
# <hr>
#
# ## Submission Checklist
#
# - All written answers are typed in Markdown cells or clearly attached separately.
# - Mathematical notation is readable, using LaTeX where helpful.
# - Code cells you rely on have been run, and their outputs are visible.
# - Final conclusions are stated in context, not only as numbers.
# - If using JupyterLite, download the completed `.ipynb` and export a PDF report.
# - Student information at the top of the notebook is complete.
# - Any screenshots or images that should appear in the PDF have been displayed through a code cell or otherwise verified in the exported PDF.

# %% [markdown]
# <hr>
#
# ## AI Usage Report
#
# Complete this section if you want your AI Usage Report to be part of this notebook/PDF submission. You may also write the AI Usage Report in a separate file and attach it separately, or include it as an appendix to your submitted PDF, according to the Canvas submission options.
#
# AI tools may be used responsibly for learning, analysis, writing, coding, and professional collaboration. AI is an efficiency tool, not a substitute for understanding. You are responsible for checking, modifying, and explaining any AI-assisted work you submit.
#
# If you used any AI tool on this assignment, your AI Usage Report must include:
#
# 1. Which AI tools were used.
# 2. Screenshots of all prompts or prompt threads that materially affected the submission.
# 3. A brief explanation of why each prompt was used.
# 4. How the AI output contributed to the final submission or helped form the final output.
# 5. How you checked, modified, or rejected the AI output before submitting.
#
# If no AI tools were used, include exactly this statement:
#
# > No AI tools were used for this submission.

# %% [markdown]
# ### Adding AI prompt screenshots in JupyterLite
#
# If you want screenshots to appear inside this notebook:
#
# 1. Save each screenshot as an image file, such as `ai_prompt_1.png`.
# 2. In JupyterLite, upload the image using the file browser on the left.
# 3. Place the image in the same `homework/` folder as this notebook, or create an `images/` folder inside `homework/`.
# 4. Reference the image with Markdown syntax for notebook reading, and use the code-display pattern below when you need the image to appear reliably in the exported PDF.
#
# Markdown examples:
#
# ```markdown
# ![Screenshot of AI prompt 1](ai_prompt_1.png)
# ```
#
# or, if the image is in `homework/images/`:
#
# ```markdown
# ![Screenshot of AI prompt 1](images/ai_prompt_1.png)
# ```
#
# The image below is a real bundled Markdown example. If it appears in your notebook, the relative path pattern is correct:
#
# ![AI Usage Report image example](images/ai_usage_report_example.png)
#
# For PDF export, also run the code cell immediately below. It displays the same image as notebook output, which is usually more reliable for PDF export than a Markdown link to an external image file. For your own report, upload your screenshot and replace `images/ai_usage_report_example.png` with your own image path.

# %%
from IPython.display import Image, display

# PDF-friendly image example. Replace the filename with your own uploaded screenshot.
display(Image(filename="images/ai_usage_report_example.png"))

# For your own screenshot saved in homework/images/, use a line like this:
# display(Image(filename="images/ai_prompt_1.png"))

# %% [markdown]
# ### AI Usage Report Answer
#
# **ANSWER:**
#
# Write your AI Usage Report here, or write: "No AI tools were used for this submission."
