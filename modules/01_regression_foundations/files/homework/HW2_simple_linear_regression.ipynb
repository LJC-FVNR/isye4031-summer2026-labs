# %% [markdown]
# # Homework 2: Simple Linear Regression
#
# This notebook is an editable homework template for simple linear regression. It contains the original problem statements, browser-friendly CSV data, and answer cells for written reasoning, plots, model fitting, prediction, and interpretation.
#
# You may complete this assignment in JupyterLite and export a PDF report, or you may complete it in another environment, in your own local Python/Jupyter environment or other approved tools, or by handwriting the written parts. The goal is to solve the problems clearly and submit work according to the course instructions.
#
# If you use this notebook, run the setup cells first. Then fill in the Markdown and code answer cells. Submit both the completed `.ipynb` and a PDF report when requested.
#
# ## Student Information
#
# Complete this section before submitting.
#
# | Field | Response |
# |---|---|
# | Name | **ANSWER:** |
# | Georgia Tech email | **ANSWER:** |
# | GTID | **ANSWER:** |

# %%
import sys
from pathlib import Path

# Homework notebooks may be opened from the module root or from the homework/ folder.
if not Path("lite_setup.py").exists() and Path("../lite_setup.py").exists():
    sys.path.append("..")

from lite_setup import ensure_packages
await ensure_packages()
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats
import statsmodels.api as sm

plt.rcParams["figure.figsize"] = (7, 4)
plt.rcParams["axes.grid"] = True

# %% [markdown]
# | Section |
# |---|
# | **Data Setup** |
#
# ## Data Setup
#
# The original Excel files have been converted to CSV so they can be read reliably inside JupyterLite. Run the next cell once before solving the coding parts.
#
# For PDF reports, the section banners mark major boundaries. If you include screenshots or other images, upload the image file and display it with the `IPython.display.Image` code-cell pattern shown in the AI Usage Report section before exporting.

# %%
from pathlib import Path

# This works whether the kernel starts at the module root or inside homework/.
data_dir = Path("homework/data")
if not data_dir.exists():
    data_dir = Path("data")

prob1 = pd.read_csv(data_dir / "hw2_prob1_accu_copiers.csv")
prob2 = pd.read_csv(data_dir / "hw2_prob2_labor_cost.csv")

print("Problem 1 data")
display(prob1)

print("Problem 2 data")
display(prob2)

# %% [markdown]
# | Section |
# |---|
# | **Problem 1: Accu-Copiers Service Time** |
#
# ## Problem 1: Accu-Copiers Service Time
#
# Accu-Copiers, Inc., sells and services the Accu-500 copying machine. As part of its standard service contract, the company agrees to perform routine services on this copier. To obtain information about the time it takes to perform routine service, the company has collected data for 11 service calls.
#
# Variables:
#
# - $x$: number of copiers serviced
# - $y$: number of minutes required
#
# Tasks:
#
# 1. Show a scatter plot of $x$ and $y$.
# 2. Based on the scatter plot, discuss why the simple linear regression model might be a good fit.
# 3. Calculate the regression line coefficients using the formulas, including the steps.
# 4. Fit the regression line with software and provide the plot.
# 5. Interpret the meaning of the slope $\beta_1$.
# 6. Interpret the meaning of the y-intercept $\beta_0$.
# 7. If the company wants to service 10 copiers, what is your expected required time?
# 8. Find an estimate for the variability of the model.

# %% [markdown]
# ### Problem 1(a) Code Answer: Scatter Plot
#
# Use the code cell below to make a scatter plot. Label both axes and give the plot a meaningful title.

# %%
# Problem 1(a)
df = prob1.copy()

# TODO: create a scatter plot of copiers_serviced versus minutes_required.
# plt.scatter(...)
# plt.xlabel(...)
# plt.ylabel(...)
# plt.title(...)
# plt.show()

# %% [markdown]
# ### Problem 1(b) Written Answer
#
# Discuss whether a straight-line relationship is reasonable based on the scatter plot. Comment on direction, strength, and whether there are obvious curvature or outlier concerns.
#
# **ANSWER:**
#
# Write your answer here.

# %% [markdown]
# ### Problem 1(c) Written + Code Answer: Formula Calculation
#
# Use the formulas
#
# $$
# \hat{\beta}_1 = \frac{S_{xy}}{S_{xx}}, \qquad
# \hat{\beta}_0 = \bar{y} - \hat{\beta}_1\bar{x},
# $$
#
# where
#
# $$
# S_{xy} = \sum_i (x_i - \bar{x})(y_i - \bar{y}), \qquad
# S_{xx} = \sum_i (x_i - \bar{x})^2.
# $$
#
# Show the quantities you calculate and state the fitted line.
#
# **ANSWER:**
#
# Write your formula work and fitted line here, then use the code cell below to check your arithmetic.

# %%
# Problem 1(c)
x = df["copiers_serviced"]
y = df["minutes_required"]

# TODO: compute xbar, ybar, Sxx, Sxy, beta1_hat, and beta0_hat using formulas.
# xbar = ...
# ybar = ...
# Sxx = ...
# Sxy = ...
# beta1_hat = ...
# beta0_hat = ...

# Print your fitted line clearly.

# %% [markdown]
# ### Problem 1(d) Code Answer: Software Fit and Regression Plot
#
# Fit the simple linear regression model with software. Report the fitted coefficients and add the regression line to the scatter plot.

# %%
# Problem 1(d)
# Suggested statsmodels pattern:
# X = sm.add_constant(df["copiers_serviced"])
# model = sm.OLS(df["minutes_required"], X).fit()
# print(model.summary())

# TODO: fit the model and plot the fitted line with the scatter plot.

# %% [markdown]
# ### Problem 1(e) Written Answer: Slope Interpretation
#
# Interpret $\hat{\beta}_1$ in the context of copier service time. Be specific about the units of $x$ and $y$.
#
# **ANSWER:**
#
# Write your answer here.

# %% [markdown]
# ### Problem 1(f) Written Answer: Intercept Interpretation
#
# Interpret $\hat{\beta}_0$ in context. Also comment on whether this interpretation is practically meaningful for this problem.
#
# **ANSWER:**
#
# Write your answer here.

# %% [markdown]
# ### Problem 1(g) Code Answer: Prediction at $x = 10$
#
# Use your fitted line to estimate the expected service time for 10 copiers.

# %%
# Problem 1(g)
x_new = 10

# TODO: compute the expected minutes required at x_new.
# predicted_minutes = ...

# Print the predicted value with units.

# %% [markdown]
# ### Problem 1(h) Code + Written Answer: Variability Estimate
#
# Estimate the model variability. In simple linear regression, this is commonly reported as the residual standard error
#
# $$
# s = \sqrt{\frac{SSE}{n-2}}.
# $$
#
# Compute it and explain what it measures in context.
#
# **ANSWER:**
#
# Write your answer here.

# %%
# Problem 1(h)

# TODO: compute residuals, SSE, MSE, and residual standard error.
# residuals = ...
# sse = ...
# mse = ...
# residual_std_error = ...

# Print your variability estimate clearly.

# %% [markdown]
# | Section |
# |---|
# | **Problem 2: Direct Labor Cost and Batch Size** |
#
# ## Problem 2: Direct Labor Cost and Batch Size
#
# An accountant wishes to predict direct labor cost $y$ on the basis of the batch size $x$ of a product produced in a job shop. Data for 12 runs are provided in the CSV loaded above.
#
# Variables:
#
# - $x$: batch size
# - $y$: direct labor cost
#
# Tasks:
#
# 1. Using a scatter plot, discuss whether a linear regression model is a good fit.
# 2. Use software to fit a regression line.
# 3. Interpret the meaning of the slope $\beta_1$.
# 4. Interpret the meaning of the y-intercept $\beta_0$.
# 5. Find an estimate for the variability of the model.

# %% [markdown]
# ### Problem 2(a) Code + Written Answer: Scatter Plot
#
# Create the scatter plot below, then write a short discussion of whether a straight-line model is reasonable.

# %%
# Problem 2(a)
df = prob2.copy()

# TODO: create a scatter plot of batch_size versus labor_cost.
# plt.scatter(...)
# plt.xlabel(...)
# plt.ylabel(...)
# plt.title(...)
# plt.show()

# %% [markdown]
# After creating the plot, write your discussion for Problem 2(a) here.
#
# **ANSWER:**
#
# Write your discussion here.

# %% [markdown]
# ### Problem 2(b) Code Answer: Software Regression Fit
#
# Fit a simple linear regression model predicting direct labor cost from batch size. Report the fitted equation and provide a regression plot.

# %%
# Problem 2(b)
# Suggested statsmodels pattern:
# X = sm.add_constant(df["batch_size"])
# model = sm.OLS(df["labor_cost"], X).fit()
# print(model.summary())

# TODO: fit the model and plot the fitted line with the scatter plot.

# %% [markdown]
# ### Problem 2(c) Written Answer: Slope Interpretation
#
# Interpret $\hat{\beta}_1$ in the context of labor cost and batch size.
#
# **ANSWER:**
#
# Write your answer here.

# %% [markdown]
# ### Problem 2(d) Written Answer: Intercept Interpretation
#
# Interpret $\hat{\beta}_0$ in context. Also comment on whether this interpretation is practically meaningful for this problem.
#
# **ANSWER:**
#
# Write your answer here.

# %% [markdown]
# ### Problem 2(e) Code + Written Answer: Variability Estimate
#
# Compute the residual standard error and explain what it measures in this context.
#
# **ANSWER:**
#
# Write your answer here.

# %%
# Problem 2(e)

# TODO: compute residuals, SSE, MSE, and residual standard error for Problem 2.
# residuals = ...
# sse = ...
# mse = ...
# residual_std_error = ...

# Print your variability estimate clearly.

# %% [markdown]
# | Section |
# |---|
# | **Submission Checklist** |
#
# ## Submission Checklist
#
# - Written explanations are complete and stated in context.
# - Plots have readable axis labels and titles.
# - Regression equations, predictions, and variability estimates are shown clearly.
# - Code cells you rely on have been run, and outputs are visible.
# - If using JupyterLite, download the completed `.ipynb` and export a PDF report.
# - Student information at the top of the notebook is complete.
# - Any screenshots or images that should appear in the PDF have been displayed through a code cell or otherwise verified in the exported PDF.

# %% [markdown]
# | Section |
# |---|
# | **AI Usage Report** |
#
# ## AI Usage Report
#
# Complete this section if you want your AI Usage Report to be part of this notebook/PDF submission. You may also write the AI Usage Report in a separate file and attach it separately, or include it as an appendix to your submitted PDF, according to the Canvas submission options.
#
# AI tools may be used responsibly for learning, analysis, writing, coding, and professional collaboration. AI is an efficiency tool, not a substitute for understanding. You are responsible for checking, modifying, and explaining any AI-assisted work you submit.
#
# If you used any AI tool on this assignment, your AI Usage Report must include:
#
# 1. Which AI tools were used.
# 2. Screenshots of all prompts or prompt threads that materially affected the submission.
# 3. A brief explanation of why each prompt was used.
# 4. How the AI output contributed to the final submission or helped form the final output.
# 5. How you checked, modified, or rejected the AI output before submitting.
#
# If no AI tools were used, include exactly this statement:
#
# > No AI tools were used for this submission.

# %% [markdown]
# ### Adding AI prompt screenshots in JupyterLite
#
# If you want screenshots to appear inside this notebook and the exported PDF:
#
# 1. Save each screenshot as an image file, such as `ai_prompt_1.png`.
# 2. In JupyterLite, upload the image using the file browser on the left.
# 3. Place the image in the `homework/images/` folder.
# 4. Run the code cell below and replace `ai_usage_report_example.png` with your own screenshot filename.
# 5. Confirm that the image output is visible before exporting the PDF.
#
# The next cell displays a bundled example image. Use the same pattern for your own AI Usage Report screenshots.

# %%
from pathlib import Path
from IPython.display import Image, display

# Image display example for PDF export. Replace the filename with your own uploaded screenshot.
image_path = Path("homework/images/ai_usage_report_example.png")
if not image_path.exists():
    image_path = Path("images/ai_usage_report_example.png")

display(Image(filename=str(image_path)))

# For your own screenshot saved in homework/images/, use the same pattern:
# image_path = Path("homework/images/ai_prompt_1.png")
# if not image_path.exists():
#     image_path = Path("images/ai_prompt_1.png")
# display(Image(filename=str(image_path)))

# %% [markdown]
# ### AI Usage Report Answer
#
# **ANSWER:**
#
# Write your AI Usage Report here, or write: "No AI tools were used for this submission."
