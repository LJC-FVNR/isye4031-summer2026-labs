# %% [markdown]
# # Logistic Regression and Classification
#
# This optional, self-contained lesson is a project-methods supplement for ISYE
# 4031. It has no homework assignment. All datasets are synthetic and are used
# only to make the statistical workflow visible.
#
# ## Learning outcomes
#
# By the end of this lesson, you should be able to:
#
# - connect probabilities, odds, log-odds, and logistic regression
# - interpret coefficients and odds ratios with appropriate conditions
# - select a decision threshold on validation data and evaluate it once on test data
#
# ## Recommended notebook order
#
# - `01_binary_response_motivation.ipynb`: See why binary response needs a probability model.
# - `02_logistic_regression_workflow.ipynb`: Fit and interpret logistic regression.
# - `03_thresholds_and_metrics.ipynb`: Evaluate thresholds and classification metrics.
#
# ## How to work in JupyterLite
#
# 1. Run the package setup cell below. The first installation can take a minute.
# 2. Open each notebook from the file browser and use **Run All Cells** from top
#    to bottom. Each notebook is independent.
# 3. Read the interpretation notes after each important table or figure; do not
#    treat successful code execution as the end of the analysis.
# 4. Use the project checklist before adapting the workflow to your own data.
# 5. Your edits are stored in this browser. Download the `.ipynb` before changing
#    devices or clearing browser storage. You may also export a PDF from
#    **File -> Save and Export Notebook As -> PDF**.

# %%
from lite_setup import ensure_packages
await ensure_packages()
# Out:
# Using the current Python environment.
