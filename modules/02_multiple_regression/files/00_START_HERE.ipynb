# %% [markdown]
# # Module 02: Multiple Regression
#
# This module turns the lecture notes and software notes into a runnable Python tutorial. By the end, you should be able to fit and interpret multiple regression models, compute the same quantities by matrix formulas, make predictions with uncertainty, and extend a regression model with curvature, interactions, and categorical predictors.
#
# Recommended order:
#
# 1. `01_mlr_big_picture.ipynb` — why multiple regression is different from simple regression.
# 2. `02_matrix_notation_and_ols.ipynb` — the design matrix and the least-squares estimator.
# 3. `03_fitting_interpreting_inference.ipynb` — coefficients, t tests, confidence intervals, F tests, and R-squared.
# 4. `04_prediction_and_intervals.ipynb` — mean-response confidence intervals and individual prediction intervals.
# 5. `05_polynomial_interaction_categorical.ipynb` — higher-order terms, interactions, and dummy variables.
# 6. `06_model_comparison_transfer.ipynb` — nested models, partial F tests, and a transfer checklist.
#
# The `homework/` folder contains JupyterLite-friendly homework templates. Those notebooks are a way to complete and export work, not a required software environment.

# %%
from lite_setup import ensure_packages
await ensure_packages()

from pathlib import Path
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as st
import statsmodels.api as sm
import statsmodels.formula.api as smf

plt.rcParams["figure.figsize"] = (7, 4)
plt.rcParams["axes.grid"] = True

# %%
delivery = pd.read_csv("data/delivery_time.csv")
delivery.head()

# %% [markdown]
# The setup cell above installs the packages needed inside JupyterLite. In a normal local Jupyter environment, it simply assumes the packages are already installed.
#
# A good habit for this course: after you load any dataset, check the column names, units, and the first few rows before fitting a model. Most regression mistakes start as data-definition mistakes.
