# %% [markdown]
# # Module 03: Diagnostics and Variable Selection
#
# This module turns regression diagnostics and screening methods into a Python workflow. It covers the main pitfalls from the lecture notes, the historical software tasks, and the homework skills for diagnostics, model comparison, categorical predictors, interactions, and partial F tests.
#
# By the end of this module, you should be able to:
#
# - diagnose common regression pitfalls using plots and model statistics;
# - compute VIF, leverage, studentized residuals, Cook's distance, DFFITS, Durbin-Watson, and hidden extrapolation checks;
# - use stepwise and best-subset procedures as screening tools rather than automatic truth machines;
# - prepare homework-style regression reports with code, interpretation, and an AI Usage Report.

# %%
from lite_setup import ensure_packages
await ensure_packages()

# %%
from pathlib import Path
import pandas as pd

for path in [
    Path('data/territory_sales.csv'),
    Path('data/process_diagnostics.csv'),
    Path('data/unusual_observations.csv'),
    Path('data/real_estate_prices.csv'),
    Path('data/insurance_adoption.csv'),
]:
    df = pd.read_csv(path)
    print(f'{path}: {df.shape[0]} rows, {df.shape[1]} columns')

# %% [markdown]
# ## Recommended Order
#
# 1. `01_regression_modeling_pitfalls.ipynb` - the modeling cycle and seven major regression pitfalls.
# 2. `02_residual_assumption_diagnostics.ipynb` - residual plots, normality, nonconstant variance, and autocorrelation.
# 3. `03_multicollinearity_extrapolation.ipynb` - VIF, correlation, coefficient instability, and hidden extrapolation.
# 4. `04_unusual_observations_influence.ipynb` - outliers, leverage, Cook's distance, DFFITS, and PRESS logic.
# 5. `05_variable_selection_screening.ipynb` - stepwise and best-subset methods in Python.
# 6. `06_transfer_model_building_checklist.ipynb` - a reusable workflow for a new regression problem.
#
# Homework notebooks are in the `homework/` folder. Your browser saves edits locally; download completed notebooks before switching devices or clearing browser storage. To submit a PDF report from JupyterLite, use `File -> Save and Export Notebook As -> PDF` after running the notebook cells you want shown in the report.
