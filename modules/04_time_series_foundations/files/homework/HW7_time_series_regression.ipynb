# %% [markdown]
# # HW7: Time-Series Regression for TRK-50 Bike Sales
#
# **Name:** <YOUR NAME>
# **Georgia Tech email:** <YOUR GT EMAIL>
# **GTID:** <YOUR GTID>
#
# You may complete this homework in JupyterLite and export a PDF report, or you may use another software environment, local Python/R, or handwritten work where appropriate. The important requirement is that your submitted work clearly answers each question and shows enough reasoning to be graded.
#
# Run the setup cell before the code cells. Written response cells include **ANSWER:** to show where your response should begin.

# %%
from pathlib import Path
import sys

module_root = Path.cwd().parent if Path.cwd().name == 'homework' else Path.cwd()
if str(module_root) not in sys.path:
    sys.path.insert(0, str(module_root))

DATA_PATH = Path('data/trk50_bike_sales.csv')
if not DATA_PATH.exists():
    DATA_PATH = Path('homework/data/trk50_bike_sales.csv')

AI_EXAMPLE_IMAGE = Path('images/ai_usage_report_example.png')
if not AI_EXAMPLE_IMAGE.exists():
    AI_EXAMPLE_IMAGE = Path('homework/images/ai_usage_report_example.png')

from lite_setup import ensure_packages
await ensure_packages()

# %%
from pathlib import Path
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.formula.api as smf
from statsmodels.stats.stattools import durbin_watson
from IPython.display import Image, display

bike = pd.read_csv(DATA_PATH)
bike.head()

# %% [markdown]
# The quarterly sales of the TRK-50 mountain bike for the previous four years are provided in `data/trk50_bike_sales.csv` inside this homework folder.
#
# The columns are:
#
# - `Year`: year number 1 through 4;
# - `Quarter`: quarter number 1 through 4;
# - `Time`: sequential time index 1 through 16;
# - `Sales`: quarterly bike sales.

# %% [markdown]
# ## Problem 1(a): Plot the Time Series
#
# Create a time-series plot of quarterly sales against `Time`.
#
# **ANSWER:**

# %%
# TODO: plot Sales versus Time.
# A line plot with markers is recommended.

# %% [markdown]
# ## Problem 1(b): Trend
#
# What kind of trend appears to exist?
#
# **ANSWER:**

# %% [markdown]
# ## Problem 1(c): Seasonal Variation
#
# What type of seasonal variation appears to exist: constant/additive or increasing/multiplicative? Explain using the plot.
#
# **ANSWER:**

# %% [markdown]
# ## Problem 1(d): Transformation Decision
#
# Is a transformation needed to obtain a series that displays constant variation? Explain.
#
# **ANSWER:**

# %% [markdown]
# ## Problem 1(e): Fit a Trend and Seasonal Model
#
# Fit an appropriate regression model with a linear trend and seasonal variation terms. Use Q1 as the baseline and create dummy variables Q2, Q3, and Q4.
#
# **ANSWER:**

# %%
# TODO: create Q2, Q3, Q4 and fit the model.
# Suggested structure:
# bike = bike.assign(
#     Q2=(bike['Quarter'] == 2).astype(int),
#     Q3=(bike['Quarter'] == 3).astype(int),
#     Q4=(bike['Quarter'] == 4).astype(int),
# )
# model = smf.ols('Sales ~ Time + Q2 + Q3 + Q4', data=bike).fit()
# print(model.summary())

# %% [markdown]
# ## Problem 1(f): Statistical Importance of Predictors
#
# Do all independent variables seem to be important? Justify your answer statistically.
#
# **ANSWER:**

# %% [markdown]
# ## Problem 1(g): Define Dummy Variables
#
# Write out the definitions of Q2, Q3, and Q4. Also explain what quarter is represented when Q2 = Q3 = Q4 = 0.
#
# **ANSWER:**

# %% [markdown]
# ## Problem 1(h): Forecast Year 5
#
# Predict bike sales in year 5, quarters 1 through 4. Report point estimates and 95% confidence and prediction intervals.
#
# **ANSWER:**

# %%
# TODO: create future rows for Time 17 to 20 and Quarter 1 to 4.
# Then use model.get_prediction(future).summary_frame(alpha=0.05).

# %% [markdown]
# ## Problem 1(i): Prediction Equation and Manual Calculation
#
# Write the fitted prediction equation and use it to calculate the forecasts for time 17 and time 18 manually.
#
# **ANSWER:**

# %%
# Optional: verify your manual calculations with Python.

# %% [markdown]
# ## AI Usage Report
#
# Use this section to write your AI Usage Report if you used AI tools while working on this assignment. Include what tool you used, what you asked it to help with, what output you used or rejected, and how you verified the final work.
#
# If you used images in your report, upload the image file to the JupyterLite file browser and display it with `IPython.display`. The example below shows the syntax using an image already included with this homework.
#
# You may also write the AI Usage Report as a separate file and submit it with your homework if that is easier.
#
# **ANSWER:**

# %%
display(Image(filename=str(AI_EXAMPLE_IMAGE)))

# %% [markdown]
# Write your AI Usage Report here.
