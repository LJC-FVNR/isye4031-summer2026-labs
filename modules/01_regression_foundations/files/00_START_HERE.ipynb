# %% [markdown]
# # Start Here: Regression Foundations in JupyterLite
#
# This is the browser-runnable version of the ISYE 4031 regression foundations tutorial. It is designed for class use and for asynchronous self-study.
#
# You can read, edit, and run every notebook directly in the browser. No Anaconda, Python installation, or package installation on your own computer is required.

# %% [markdown]
# ## How to use this tutorial
#
# 1. Run the setup cell below. The first run can take a little time while the browser loads Python packages.
# 2. Open the notebooks from the file browser on the left, or use the links below.
# 3. Run each notebook from top to bottom.
# 4. When you see `PASS`, a checkpoint has verified a computable result.
# 5. Save or download completed notebooks before changing browser/device or clearing browser storage.
# 6. For homework-style work, complete the student information table, run all cells, submit the completed `.ipynb`, and export a PDF report with `File` -> `Save and Export Notebook As` -> `PDF`. If your report includes screenshots or uploaded images, use the `IPython.display.Image` code-cell pattern shown in the homework template and check the exported PDF before submitting.
#
# Suggested order:
#
# - `01_forecasting_context.ipynb`
# - `02_statistical_review.ipynb`
# - `03_python_setup_and_data.ipynb`
# - `04_slr_workflow.ipynb`
# - `05_inference_intervals_prediction.ipynb`
# - `06_residual_diagnostics.ipynb`
# - `07_transfer_to_new_problem.ipynb`
#
# Homework templates:
#
# - `homework/HW1_statistical_review.ipynb`
# - `homework/HW2_simple_linear_regression.ipynb`
#
# You may complete homework in JupyterLite and export a PDF report, or use another environment, local software, or handwritten work when appropriate. Follow the course submission instructions for what to upload.

# %% [markdown]
# ## Browser package setup
#
# Run the next cell before the first analysis cell. It loads the scientific Python packages used in this module into the browser-based Python kernel.
#
# The first run in a browser session can take a little time. Later notebooks usually load faster because the browser can reuse cached packages.

# %%
from lite_setup import ensure_packages
await ensure_packages()

# %% [markdown]
# ## Quick environment check
#
# The next cell confirms that the tutorial files are visible to the browser Python kernel and that the data can be loaded with the same relative path used throughout the module.

# %%
import pandas as pd
from checks import check_columns

fuel = pd.read_csv("data/fuelcons.csv")
print(fuel.head())
print(check_columns(fuel, ["week", "Temp", "Fuelcons"]))

# %% [markdown]
# ## What this module teaches
#
# By the end of the module, you should be able to:
#
# - distinguish time-series and cross-sectional forecasting contexts,
# - explain the statistical ideas used by simple linear regression,
# - fit and interpret a simple linear regression model in Python,
# - compute confidence intervals and prediction intervals,
# - diagnose residual patterns,
# - transfer the workflow to a new small forecasting problem.
#
# Start with `01_forecasting_context.ipynb` when you are ready.
