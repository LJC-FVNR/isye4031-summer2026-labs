# %% [markdown]
# # Module 04: Time Series Foundations
#
# This module turns the time-series lecture notes and software notes into a Python workflow for regression-based forecasting. It focuses on time-indexed data, trend models, seasonal dummy variables, transformations for changing seasonal swing, and autocorrelation diagnostics.
#
# By the end of this module, you should be able to:
#
# - recognize trend, seasonal, cyclical, and irregular components in a plotted series;
# - fit no-trend, linear trend, quadratic trend, and trend-plus-seasonality regression models;
# - decide when additive seasonality is reasonable and when a transformation such as log is useful;
# - create and interpret seasonal dummy variables with a baseline season;
# - diagnose residual autocorrelation with time plots, runs, and Durbin-Watson;
# - build a homework-style forecast report with code, intervals, interpretation, and an AI Usage Report.

# %%
from lite_setup import ensure_packages
await ensure_packages()

# %%
from pathlib import Path
import pandas as pd

for path in [
    Path('data/cod_catch.csv'),
    Path('data/calculator_sales.csv'),
    Path('data/loan_requests.csv'),
    Path('data/hotel_rooms.csv'),
    Path('data/autocorrelated_demand.csv'),
    Path('data/trk50_bike_sales.csv'),
]:
    df = pd.read_csv(path)
    print(f'{path}: {df.shape[0]} rows, {df.shape[1]} columns')

# %% [markdown]
# ## Recommended Order
#
# 1. `01_time_series_components.ipynb` - time-series data, components, and plots.
# 2. `02_trend_regression_models.ipynb` - no-trend, linear trend, and quadratic trend regression.
# 3. `03_seasonality_dummy_variables.ipynb` - seasonal dummy variables and baseline interpretation.
# 4. `04_transformations_and_multiplicative_seasonality.ipynb` - transformations for changing seasonal swing.
# 5. `05_autocorrelation_diagnostics.ipynb` - residual time plots, runs, and Durbin-Watson.
# 6. `06_autocorrelation_adjusted_forecasting.ipynb` - first-order autocorrelation and approximate adjusted forecasts.
# 7. `07_transfer_forecasting_checklist.ipynb` - a reusable workflow for new time-series regression problems.
#
# Homework notebooks are in the `homework/` folder. Your browser saves edits locally; download completed notebooks before switching devices or clearing browser storage. To submit a PDF report from JupyterLite, use `File -> Save and Export Notebook As -> PDF` after running the notebook cells you want shown in the report.
